# %%
# data是什么

import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

import dataloader

data = dataloader.load_case_data()
print(type(data))
print(data.keys())
print(type(data['gens']))
print(type(data['gens'][0]))
print(data['gens'][1].upper)
data['gens'][1].calculate_upper(1,13)
print(data['gens'][1].upper)
# Out:
# <class 'dict'>
# dict_keys(['buses', 'lines', 'gens', 'storages'])
# <class 'list'>
# <class 'data.Gen'>
# 35.587506191550375
# 34.83171424140472
