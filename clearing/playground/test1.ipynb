# %%
file_path = '../data_PROSPECT43/load_PROSPECT43.mat'
file_path2 = '../data_PROSPECT43/vre_PROSPECT43.mat'


import scipy.io

data = scipy.io.loadmat(file_path)
print(type(data))
print(data.keys())
print(type(data['load_R1']))
print(data['load_R1'].shape)
print(data['load_R1'][0,:,:,5].shape)
print(data['load_R1'][0,100,12,5])

print('='*50)
data2 = scipy.io.loadmat(file_path2)
print(type(data2))
print(data2.keys())
print(type(data2['solar_case']))
print(data2['solar_case'].shape)
print(type(data2['solar_case'][0,0]))
print(data2['solar_case'][0,0].dtype.names)
print(type(data2['solar_case'][0,0]['solar_R1']))
print(data2['solar_case'][0,0]['solar_R1'].shape)
print(data2['solar_case'][0,0]['solar_R1'][0,:,:].shape)
print(data2['solar_case'][0,0]['solar_R1'][0,:,:][100][12])

print('='*50)
# Out:
# <class 'dict'>
# dict_keys(['__header__', '__version__', '__globals__', 'load_R1', 'load_R2', 'load_R3', 'load_R4', 'load_R5'])
# <class 'numpy.ndarray'>
# (8, 365, 24, 6)
# (365, 24)
# 22295.658349005476
# ...
# <class 'dict'>
# dict_keys(['__header__', '__version__', '__globals__', 'solar_case', 'solar_dis_case', 'wind_case', 'wind_ofs_case'])
# <class 'numpy.ndarray'>
# (1, 1)
# <class 'numpy.void'>
# ('solar_R1', 'solar_R2', 'solar_R3', 'solar_R4', 'solar_R5', 'solar_ER1', 'solar_ER2', 'solar_ER3')
# <class 'numpy.ndarray'>
# (8, 365, 24)
# (365, 24)
# 0.5291058584437917
# ...
